# %% [markdown]
# # Titanic Analysing

# %% [markdown]
# ## Import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Data Extraction

# %%
titanic_df = sns.load_dataset("titanic")
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# %%sql

# %% [markdown]
# ## Passengers who boarded the ship from different cities

# %%
encoder = LabelEncoder()
encoded_town = encoder.fit_transform(titanic_df["embark_town"])

town_id , count = np.unique(encoded_town, return_counts=True)

print(dict(zip(encoder.classes_, count)))

#pie chart

plt.pie(count, labels=encoder.classes_, autopct='%1.2f%%')
plt.show()
# Out:
# {'Cherbourg': np.int64(168), 'Queenstown': np.int64(77), 'Southampton': np.int64(644), nan: np.int64(2)}

# %% [markdown]
# ## Passengers in each class

# %%
pclass_ids, count = np.unique(titanic_df["pclass"], return_counts=True)

print(dict(zip(pclass_ids, counts)))

#pie chart

class_names = ["First Class", "Second Class", "Third Class"]
plt.pie(count, labels=class_names, autopct='%1.2f%%')
plt.show()
# Out:
# {np.int64(1): np.int64(216), np.int64(2): np.int64(184), np.int64(3): np.int64(491)}

# %% [markdown]
# ## Impact of different variables on survival

# %%
sns.pairplot(titanic_df, hue="survived")
plt.show()
